# %% [markdown]
# Day1 HW

# %% [markdown]
# #1<br>
# <font size = 4>核心問題:</font><br>
# --尋找麋鹿的最佳路徑<br>
# <font size = 4>資料來源:</font><br>
# --由Kaggle提供城市列表及座標<br>
# <font size = 4>資料型態:</font><br>
# --結構化資料<br>
# <font size = 4>驗證評估:</font><br>
# --prime, greedy algorithm<br>

# %% [markdown]
# #2<br>
# <font size = 4>核心問題: </font><br>
# --車隊的營收來源 --- 乘客,司機,廣告<br>
# --怎麼提升業績 --- 增加乘客和司機及廣告投入<br>
# --如何吸引司機加入 --- 提高司機設備和福利 例:排班權<br>
# --如何吸引乘客 --- 增加乘客便利性 例:方便叫車及付款<br>
# --什麼時間點最多人叫車<br>
# <font size = 4>資料來源:</font><br>
# --載客數<br>
# --載客時程<br>
# --營業時程<br>
# --營業里程<br>
# --平均日收入<br>
# --總收入<br>
# --空車率<br>
# <font size = 4>資料蒐集:</font><br>
# --交通部 計程車營運狀況調查報告,計程車研究網..等<br>
# <font size = 4>資料型態:</font><br>
# --結構化資料<br>
# <font size = 4>驗證評估:</font><br>
# --以營業行為(載客時程,載客里程...等)將司機分類<br>
#     - Cluster Analysis<br>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0,100,101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 13.018

# %%
def mean_squared_error(y,yp):
    """
    ----- day1 HW #3 -----
    計算MSE
    Args:
        - y : 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    MSE = mse = sum(pow(y - yp, 2)) / len(y)
    return mse
MSE = mean_squared_error(y,y_hat)
print("The mean squared error is %.3f" % (MSE))
# Out:
# The mean squared error is 259.060

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 191.522
# The Mean absolute error is 10.829
